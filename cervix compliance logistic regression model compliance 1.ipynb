# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf

# %%
df = pd.read_csv('Data Collection Form_Cervix Cancer - V1_De_identified.csv')

# %%
df.head()
# Out:
#    Study Code  Age Stage of Malignancy  ECOG Performance Status  \
# 0           1   65               IIIC1                      0.0
# 1           2   30                IIIC                      0.0
# 2           3   40                 IIA                      0.0
# 3           4   45                IIIC                      0.0
# 4           7   81                 IB1                      0.0
#
#   Suburb of Residence  SEIFA Score  SEIFA Quartile  Postcode Valid  MMM Code  \
# 0          Merrylands   871.951173               1      2160     Y         1
# 1            Katoomba   963.855346               2      2780     Y         1
# 2             Penrith   933.728338               2      2750     Y         1
# 3     Guildford (NSW)   822.753387               1      2161     Y         1
# 4           Glossodia  1041.424531               4      2756     Y         2
#
#    ... Stage Simplified Time 1 - Compliance Time 2 - Compliant  \
# 0  ...           III/IV       Non-Compliant          Compliant
# 1  ...           III/IV       Non-Compliant          Compliant
# 2  ...             I/II       Non-Compliant          Compliant
# 3  ...           III/IV       Non-Compliant      Non-Compliant
# 4  ...             I/II                 NaN                NaN
#
#   Time 3 - Compliant In Area/Out of Area Time 1 Categories  \
# 0                NaN                                   2.0
# 1          Compliant                                   4.0
# 2                NaN                                   4.0
# 3          Compliant                                   2.0
# 4                NaN                                   NaN
#
#   In Area/Out of Area Time 2 Categories In Area/Out of Area Time 3 Categories  \
# 0                                   1.0                                   NaN
# 1                                   3.0                                   3.0
# 2                                   3.0                                   NaN
# 3                                   2.0                                   1.0
# 4                                   NaN                                   NaN
#
#   IRSD (Time Frame 1) IRSD (Time Frame 2) IRSD (Time Frame 3)
# 0                 2.0                 1.0                 NaN
# 1                 4.0                 3.0                 3.0
# 2                 4.0                 3.0                 NaN
# 3                 2.0                 2.0                 1.0
# 4                 NaN                 NaN                 NaN
#
# [5 rows x 56 columns]

# %%
df['Metro'] = [1 if x == 1 else 0 for x in df['MMM Code']]

# %%
predictors = [
    'Age',
    'SEIFA Score',
    'Metro',
    'Route of Referral',
    'Provider Type of Gynaecologist Appointment',
    'In Area/Out of Area',
    'Stage Simplified'
]


outcome_variables = [
    'Time 1 - Compliance',
    'Time 2 - Compliant',
    'Time 3 - Compliant'

]
X = df[predictors]

# %%
X.head()
# Out:
#    Age  SEIFA Score  Metro Route of Referral  \
# 0   65   871.951173      1       GP Referred
# 1   30   963.855346      1       GP Referred
# 2   40   933.728338      1       GP Referred
# 3   45   822.753387      1       GP Referred
# 4   81  1041.424531      0       GP Referred
#
#   Provider Type of Gynaecologist Appointment In Area/Out of Area  \
# 0                                        NaN             In Area
# 1                                     Public         Out of Area
# 2                                        NaN         Out of Area
# 3                                    Private             In Area
# 4                                    Private         Out of Area
#
#   Stage Simplified
# 0           III/IV
# 1           III/IV
# 2             I/II
# 3           III/IV
# 4             I/II

# %%
X.isnull().sum()
# Out:
# Age                                            0
# SEIFA Score                                    0
# Metro                                          0
# Route of Referral                              0
# Provider Type of Gynaecologist Appointment    33
# In Area/Out of Area                            0
# Stage Simplified                               0
# dtype: int64

# %%
df['MMM Code'].value_counts()
# Out:
# MMM Code
# 1    147
# 5     16
# 3     12
# 4     11
# 2      2
# 7      1
# Name: count, dtype: int64

# %%
df[outcome_variables].isnull().sum()
# Out:
# Time 1 - Compliance    11
# Time 2 - Compliant      2
# Time 3 - Compliant     61
# dtype: int64

# %%
y = pd.get_dummies(df[outcome_variables[0]],drop_first=True,dtype = int,dummy_na = True,prefix='y')

# %%
sub_y = y.query('y_nan == 0')
data_index = sub_y.index

# %%
sub_y
# Out:
#      y_Non-Compliant  y_nan
# 0                  1      0
# 1                  1      0
# 2                  1      0
# 3                  1      0
# 5                  1      0
# ..               ...    ...
# 184                1      0
# 185                0      0
# 186                0      0
# 187                0      0
# 188                0      0
#
# [178 rows x 2 columns]

# %%
def plot_partial_residual(model,feature,X,y):

    # Compute partial residuals for X1
    pred_logit = model.predict(X)  # Predicted log-odds
    residuals = y - pred_logit  # Compute residuals
    partial_residual = X[feature]* model.params[feature] + residuals  # Partial residuals

    # Plot Partial Residuals
    sns.scatterplot(x=X[feature], y=partial_residual, alpha=0.6,hue=y)
    sns.regplot(x=X[feature], y=partial_residual, scatter=False, lowess=True, color='red')  # LOWESS curve

    plt.axhline(y=0, linestyle='--', color='black', alpha=0.7)
    plt.xlabel(feature)
    plt.ylabel("Partial Residuals")
    plt.title("Partial Residual Plot for {}".format(feature))
    plt.show()

# %%
X = df.loc[data_index,predictors]
X = pd.get_dummies(X,drop_first=True,dtype = int,columns =  [
    'Route of Referral',
    'In Area/Out of Area',
    'Stage Simplified'
])
X = pd.get_dummies(X,dummy_na = True,drop_first=True,dtype = int,columns= ['Provider Type of Gynaecologist Appointment'])

# %%
#X['Age'] = (X['Age'] - np.mean(X['Age']))/np.std(X['Age'])
#X['SEIFA Score'] = (X['SEIFA Score'] - np.mean(X['SEIFA Score']))/np.std(X['SEIFA Score'])

# %%
X.columns
# Out:
# Index(['Age', 'SEIFA Score', 'Metro', 'Route of Referral_GP Referred',
#        'In Area/Out of Area_Out of Area', 'Stage Simplified_III/IV',
#        'Provider Type of Gynaecologist Appointment_Public',
#        'Provider Type of Gynaecologist Appointment_nan'],
#       dtype='object')

# %%
pd.concat([sub_y['y_Non-Compliant'],X],axis=1).corr()
# Out:
#                                                    y_Non-Compliant       Age  \
# y_Non-Compliant                                           1.000000 -0.071322
# Age                                                      -0.071322  1.000000
# SEIFA Score                                              -0.015647  0.022812
# Metro                                                     0.134699 -0.060146
# Route of Referral_GP Referred                             0.057542 -0.110000
# In Area/Out of Area_Out of Area                          -0.023014 -0.080892
# Stage Simplified_III/IV                                  -0.104994 -0.159268
# Provider Type of Gynaecologist Appointment_Public         0.143988  0.011978
# Provider Type of Gynaecologist Appointment_nan           -0.146197  0.001871
#
#                                                    SEIFA Score     Metro  \
# y_Non-Compliant                                      -0.015647  0.134699
# Age                                                   0.022812 -0.060146
# SEIFA Score                                           1.000000  0.070377
# Metro                                                 0.070377  1.000000
# Route of Referral_GP Referred                         0.198687  0.074008
# In Area/Out of Area_Out of Area                      -0.016168 -0.462832
# Stage Simplified_III/IV                              -0.122073  0.032332
# Provider Type of Gynaecologist Appointment_Public    -0.257283  0.007016
# Provider Type of Gynaecologist Appointment_nan        0.075199  0.082695
#
#                                                    Route of Referral_GP Referred  \
# y_Non-Compliant                                                         0.057542
# Age                                                                    -0.110000
# SEIFA Score                                                             0.198687
# Metro                                                                   0.074008
# Route of Referral_GP Referred                                           1.000000
# In Area/Out of Area_Out of Area                                         0.003288
# Stage Simplified_III/IV                                                -0.002985
# Provider Type of Gynaecologist Appointment_Public                      -0.408874
# Provider Type of Gynaecologist Appointment_nan                          0.108817
#
#                                                    In Area/Out of Area_Out of Area  \
# y_Non-Compliant                                                          -0.023014
# Age                                                                      -0.080892
# SEIFA Score                                                              -0.016168
# Metro                                                                    -0.462832
# Route of Referral_GP Referred                                             0.003288
# In Area/Out of Area_Out of Area                                           1.000000
# Stage Simplified_III/IV                                                   0.036185
# Provider Type of Gynaecologist Appointment_Public                         0.052146
# Provider Type of Gynaecologist Appointment_nan                           -0.075933
#
#                                                    Stage Simplified_III/IV  \
# y_Non-Compliant                                                  -0.104994
# Age                                                              -0.159268
# SEIFA Score                                                      -0.122073
# Metro                                                             0.032332
# Route of Referral_GP Referred                                    -0.002985
# In Area/Out of Area_Out of Area                                   0.036185
# Stage Simplified_III/IV                                           1.000000
# Provider Type of Gynaecologist Appointment_Public                -0.005209
# Provider Type of Gynaecologist Appointment_nan                   -0.010497
#
#                                                    Provider Type of Gynaecologist Appointment_Public  \
# y_Non-Compliant                                                                             0.143988
# Age                                                                                         0.011978
# SEIFA Score                                                                                -0.257283
# Metro                                                                                       0.007016
# Route of Referral_GP Referred                                                              -0.408874
# In Area/Out of Area_Out of Area                                                             0.052146
# Stage Simplified_III/IV                                                                    -0.005209
# Provider Type of Gynaecologist Appointment_Public                                           1.000000
# Provider Type of Gynaecologist Appointment_nan                                             -0.420830
#
#                                                    Provider Type of Gynaecologist Appointment_nan
# y_Non-Compliant                                                                         -0.146197
# Age                                                                                      0.001871
# SEIFA Score                                                                              0.075199
# Metro                                                                                    0.082695
# Route of Referral_GP Referred                                                            0.108817
# In Area/Out of Area_Out of Area                                                         -0.075933
# Stage Simplified_III/IV                                                                 -0.010497
# Provider Type of Gynaecologist Appointment_Public                                       -0.420830
# Provider Type of Gynaecologist Appointment_nan                                           1.000000

# %%
sns.kdeplot(x=X['Age'],hue=sub_y['y_Non-Compliant'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
fig, ax = plt.subplots(2, 4)
fig.set_size_inches(20,20)
for c,a in zip(X.columns,ax.ravel()):
    sns.regplot(x=X[c], y=sub_y['y_Non-Compliant'],logistic=True,ax=a)

# %%
X.columns
# Out:
# Index(['Age', 'SEIFA Score', 'Metro', 'Route of Referral_GP Referred',
#        'In Area/Out of Area_Out of Area', 'Stage Simplified_III/IV',
#        'Provider Type of Gynaecologist Appointment_Public',
#        'Provider Type of Gynaecologist Appointment_nan'],
#       dtype='object')

# %%
def formula_from_cols(df, y):
    return y + ' ~ ' + ' + '.join([col for col in df.columns if not col==y])

# %%
formula_from_cols(X,'y_Non-Compliant')
# Out:
# 'y_Non-Compliant ~ Age + SEIFA Score + Metro + Route of Referral_GP Referred + In Area/Out of Area_Out of Area + Stage Simplified_III/IV + Provider Type of Gynaecologist Appointment_Public + Provider Type of Gynaecologist Appointment_nan'

# %%
# Fit the logistic regression model using statsmodels
X = sm.add_constant(X)  # Add intercept

model = sm.Logit(sub_y['y_Non-Compliant'],X).fit()

# Print model summary
print(model.summary())
print(model.bic)
print(model.aic)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.558408
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        y_Non-Compliant   No. Observations:                  178
# Model:                          Logit   Df Residuals:                      169
# Method:                           MLE   Df Model:                            8
# Date:                Wed, 26 Mar 2025   Pseudo R-squ.:                 0.06777
# Time:                        20:07:38   Log-Likelihood:                -99.397
# converged:                       True   LL-Null:                       -106.62
# Covariance Type:            nonrobust   LLR p-value:                   0.07072
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                 1.0331      2.206      0.468      0.640      -3.291       5.357
# Age                                                  -0.0121      0.013     -0.952      0.341      -0.037       0.013
# SEIFA Score                                          -0.0005      0.002     -0.269      0.788      -0.004       0.003
# Metro                                                 0.8294      0.479      1.733      0.083      -0.109       1.768
# Route of Referral_GP Referred                         0.6494      0.463      1.403      0.160      -0.258       1.556
# In Area/Out of Area_Out of Area                       0.1525      0.411      0.371      0.711      -0.654       0.959
# Stage Simplified_III/IV                              -0.5879      0.361     -1.627      0.104      -1.296       0.120
# Provider Type of Gynaecologist Appointment_Public     0.6913      0.454      1.523      0.128      -0.198       1.581
# Provider Type of Gynaecologist Appointment_nan       -0.6170      0.477     -1.294      0.196      -1.551       0.317
# =====================================================================================================================
# 245.42945280553056
# 216.79340085290178

# %%
# Add log-transformed versions of continuous predictors


log_X = X.copy(deep=True) # Add intercept
log_X['Age_log'] = log_X['Age'] * np.log(log_X['Age'])
log_X['SEIFA_log'] = log_X['SEIFA Score'] * np.log(log_X['SEIFA Score'])

# Fit logistic regression model
log_model = sm.Logit(sub_y['y_Non-Compliant'],log_X).fit()

# Print summary
print(log_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.558116
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        y_Non-Compliant   No. Observations:                  178
# Model:                          Logit   Df Residuals:                      167
# Method:                           MLE   Df Model:                           10
# Date:                Mon, 24 Mar 2025   Pseudo R-squ.:                 0.06826
# Time:                        20:14:05   Log-Likelihood:                -99.345
# converged:                       True   LL-Null:                       -106.62
# Covariance Type:            nonrobust   LLR p-value:                    0.1491
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                 1.5084     23.677      0.064      0.949     -44.898      47.914
# Age                                                   0.1228      0.434      0.283      0.777      -0.727       0.973
# SEIFA Score                                          -0.0172      0.197     -0.087      0.930      -0.404       0.370
# Metro                                                 0.8177      0.483      1.694      0.090      -0.129       1.764
# Route of Referral_GP Referred                         0.6602      0.464      1.422      0.155      -0.250       1.570
# In Area/Out of Area_Out of Area                       0.1462      0.417      0.351      0.726      -0.671       0.963
# Stage Simplified_III/IV                              -0.5896      0.362     -1.629      0.103      -1.299       0.120
# Provider Type of Gynaecologist Appointment_Public     0.6967      0.454      1.534      0.125      -0.194       1.587
# Provider Type of Gynaecologist Appointment_nan       -0.6327      0.480     -1.318      0.188      -1.574       0.308
# Age_log                                              -0.0269      0.086     -0.311      0.756      -0.196       0.143
# SEIFA_log                                             0.0021      0.025      0.085      0.932      -0.047       0.052
# =====================================================================================================================

# %% [markdown]
# Box-Tidwell Test suggests that both age and seifa does not have a non linear term

# %%
for c in X.columns:
    plot_partial_residual(model,c,X,sub_y['y_Non-Compliant'])
# Out:
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),

# %%
from scipy.interpolate import BSpline
knots = np.percentile(X['Age'], [25,50,75])  # Specify knot locations
degree = 2  # Cubic spline

# Generate basis functions
x = np.linspace(min(X['Age']), max(X['Age']), 100)
spl = BSpline.basis_element(knots)

# Plot the B-spline basis
plt.plot(x, spl(x))
plt.title("B-Spline Basis Function")
plt.show()

# %%
# Fit the logistic regression model using statsmodels
new_X = X.copy(deep=True) 


new_X['Age'] = (new_X['Age'] - np.mean(new_X['Age']))/np.std(new_X['Age'])
new_X['SEIFA Score'] = (new_X['SEIFA Score'] - np.mean(new_X['SEIFA Score']))/np.std(new_X['SEIFA Score'])

new_X['RouteSEIFA'] = X['Route of Referral_GP Referred']*X['SEIFA Score'] 
#new_X['StageSEIFA'] = X['Provider Type of Gynaecologist Appointment_Public']*X['Age']**0.5
#new_X['AgeInArea'] = X['In Area/Out of Area_Out of Area']*X['Age'] # 286.5 254.2

#new_X['AgeStage'] = X['Route of Referral_GP Referred']*X['Age'] # 
#new_X['Age2'] = spl(X['Age'])
#new_X = new_X.drop(['Age'],axis=1)


new_model = sm.Logit(sub_y['y_Non-Compliant'],new_X).fit()

# Print model summary
print(new_model.summary())
print(new_model.bic)
print(new_model.aic)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.544114
#          Iterations 6
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        y_Non-Compliant   No. Observations:                  178
# Model:                          Logit   Df Residuals:                      168
# Method:                           MLE   Df Model:                            9
# Date:                Wed, 26 Mar 2025   Pseudo R-squ.:                 0.09163
# Time:                        20:08:39   Log-Likelihood:                -96.852
# converged:                       True   LL-Null:                       -106.62
# Covariance Type:            nonrobust   LLR p-value:                   0.02097
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                 0.0724      0.744      0.097      0.922      -1.385       1.530
# Age                                                  -0.1947      0.183     -1.065      0.287      -0.553       0.164
# SEIFA Score                                           0.5162      0.318      1.623      0.105      -0.107       1.140
# Metro                                                 1.0222      0.494      2.070      0.038       0.054       1.990
# Route of Referral_GP Referred                         9.7257      4.172      2.331      0.020       1.548      17.903
# In Area/Out of Area_Out of Area                       0.1392      0.422      0.330      0.742      -0.688       0.967
# Stage Simplified_III/IV                              -0.6890      0.371     -1.859      0.063      -1.415       0.037
# Provider Type of Gynaecologist Appointment_Public     0.6529      0.466      1.401      0.161      -0.261       1.566
# Provider Type of Gynaecologist Appointment_nan       -0.7200      0.485     -1.485      0.138      -1.670       0.230
# RouteSEIFA                                           -0.0096      0.004     -2.185      0.029      -0.018      -0.001
# =====================================================================================================================
# 245.52235290331728
# 213.70451740039644

# %%
from scipy.stats import chi2

lr_stat = 2 * (new_model.llf - model.llf)
p_value = chi2.sf(lr_stat, df=len(new_model.params) - len(model.params))
print(p_value)
# Out:
# 0.017411004136736505

# %%
for c in new_X.columns:
    plot_partial_residual(new_model,c,new_X,sub_y['y_Non-Compliant'])
# Out:
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:226: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),

# %%
X['fitted'] = model.predict(X)
X['fitted_squared'] = X['fitted'] ** 2

## neither is significant
## model does not explain the data well
link_test = sm.Logit(sub_y['y_Non-Compliant'], X[['const', 'fitted', 'fitted_squared']]).fit()
print(link_test.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.655200
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        y_Non-Compliant   No. Observations:                  187
# Model:                          Logit   Df Residuals:                      184
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 23 Mar 2025   Pseudo R-squ.:                 0.03799
# Time:                        21:13:04   Log-Likelihood:                -122.52
# converged:                       True   LL-Null:                       -127.36
# Covariance Type:            nonrobust   LLR p-value:                  0.007920
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -2.4753      2.042     -1.212      0.225      -6.477       1.527
# fitted             6.0742      9.599      0.633      0.527     -12.740      24.889
# fitted_squared    -2.1975     10.845     -0.203      0.839     -23.453      19.058
# ==================================================================================

# %%
import statsmodels.stats.outliers_influence as oi

infl = model.get_influence()
cooks_d = infl.cooks_distance[0]

# Identify points with high Cook's distance
influential_points = np.where(cooks_d > 4 / len(X))[0]
print("Influential Points:", influential_points)
# Out:
# Influential Points: [ 22  51 169]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif_data = pd.DataFrame()
vif_data["Feature"] = new_X.columns
vif_data["VIF"] = [variance_inflation_factor(new_X.values, i) for i in range(new_X.shape[1])]
print(vif_data)
# Out:
#                                              Feature         VIF
# 0                                              const   17.068659
# 1                                        SEIFA Score   10.958568
# 2                                              Metro  221.572503
# 3                      Route of Referral_GP Referred    1.232635
# 4                            Stage Simplified_III/IV    1.022112
# 5  Provider Type of Gynaecologist Appointment_Public    1.550238
# 6     Provider Type of Gynaecologist Appointment_nan    1.261186
# 7                                          AgeInArea    1.339576
# 8                                         MetroSEIFA  238.035657
# 9                                               Age2    1.013212

# %%
X['Age_logAge'] = X['Age'] * np.log(X['Age'])

# Fit logistic regression with interaction term
age = sm.add_constant(X[['Age', 'Age_logAge']])
model = sm.Logit(sub_y['y_Non-Compliant'], age).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.667447
#          Iterations 5
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        y_Non-Compliant   No. Observations:                  187
# Model:                          Logit   Df Residuals:                      184
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 23 Mar 2025   Pseudo R-squ.:                 0.02001
# Time:                        18:43:05   Log-Likelihood:                -124.81
# converged:                       True   LL-Null:                       -127.36
# Covariance Type:            nonrobust   LLR p-value:                   0.07823
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.0473      3.880      1.816      0.069      -0.557      14.651
# Age           -0.7387      0.367     -2.014      0.044      -1.458      -0.020
# Age_logAge     0.1497      0.074      2.037      0.042       0.006       0.294
# ==============================================================================

# %%
X['SEIFA_logSEIFA'] = X['SEIFA Score'] * np.log(X['SEIFA Score'])

# Fit logistic regression with interaction term
seifa = sm.add_constant(X[['SEIFA Score', 'SEIFA_logSEIFA']])
model = sm.Logit(sub_y['y_Non-Compliant'], seifa).fit()
print(model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.680392
#          Iterations 4
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:        y_Non-Compliant   No. Observations:                  187
# Model:                          Logit   Df Residuals:                      184
# Method:                           MLE   Df Model:                            2
# Date:                Sun, 23 Mar 2025   Pseudo R-squ.:                0.001001
# Time:                        18:43:10   Log-Likelihood:                -127.23
# converged:                       True   LL-Null:                       -127.36
# Covariance Type:            nonrobust   LLR p-value:                    0.8803
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              2.7699     17.913      0.155      0.877     -32.339      37.879
# SEIFA Score       -0.0318      0.153     -0.207      0.836      -0.332       0.268
# SEIFA_logSEIFA     0.0042      0.020      0.212      0.832      -0.034       0.043
# ==================================================================================

# %%
X = df.loc[data_index,predictors]
X = pd.get_dummies(X,drop_first=True,dtype = int,columns =  [
    'Route of Referral',
    'In Area/Out of Area',
    'Stage Simplified'
])
X = pd.get_dummies(X,dummy_na = True,drop_first=True,dtype = int,columns= ['Provider Type of Gynaecologist Appointment'])

X = sm.add_constant(X)

# Probit Model
model_probit = sm.Probit(sub_y['y_Non-Compliant'], X).fit()
print(model_probit.summary())

# Complementary Log-Log Model
model_cloglog = sm.GLM(sub_y['y_Non-Compliant'], X, family=sm.families.Binomial(link=sm.families.links.cloglog())).fit()
print(model_cloglog.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.654443
#          Iterations 4
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:        y_Non-Compliant   No. Observations:                  187
# Model:                         Probit   Df Residuals:                      178
# Method:                           MLE   Df Model:                            8
# Date:                Sun, 23 Mar 2025   Pseudo R-squ.:                 0.03910
# Time:                        18:43:30   Log-Likelihood:                -122.38
# converged:                       True   LL-Null:                       -127.36
# Covariance Type:            nonrobust   LLR p-value:                    0.2679
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                -0.3333      1.173     -0.284      0.776      -2.632       1.965
# Age                                                   0.0048      0.007      0.701      0.484      -0.009       0.018
# SEIFA Score                                           0.0004      0.001      0.418      0.676      -0.002       0.003
# Metro                                                -0.6667      0.265     -2.511      0.012      -1.187      -0.146
# Route of Referral_GP Referred                         0.2943      0.250      1.179      0.239      -0.195       0.784
# In Area/Out of Area_Out of Area                      -0.3349      0.220     -1.522      0.128      -0.766       0.096
# Stage Simplified_III/IV                              -0.0698      0.192     -0.364      0.716      -0.446       0.306
# Provider Type of Gynaecologist Appointment_Public     0.0129      0.233      0.055      0.956      -0.444       0.470
# Provider Type of Gynaecologist Appointment_nan       -0.2862      0.282     -1.014      0.311      -0.839       0.267
# =====================================================================================================================
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:        y_Non-Compliant   No. Observations:                  187
# Model:                            GLM   Df Residuals:                      178
# Model Family:                Binomial   Df Model:                            8
# Link Function:                cloglog   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -122.40
# Date:                Sun, 23 Mar 2025   Deviance:                       244.80
# Time:                        18:43:30   Pearson chi2:                     186.
# No. Iterations:                     7   Pseudo R-squ. (CS):            0.05169
# Covariance Type:            nonrobust
# =====================================================================================================================
#                                                         coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------------
# const                                                -0.9199      1.491     -0.617      0.537      -3.841       2.002
# Age                                                   0.0059      0.008      0.718      0.473      -0.010       0.022
# SEIFA Score                                           0.0007      0.001      0.511      0.609      -0.002       0.003
# Metro                                                -0.8153      0.321     -2.538      0.011      -1.445      -0.186
# Route of Referral_GP Referred                         0.3483      0.316      1.104      0.270      -0.270       0.967
# In Area/Out of Area_Out of Area                      -0.4047      0.288     -1.407      0.159      -0.968       0.159
# Stage Simplified_III/IV                              -0.0813      0.236     -0.345      0.730      -0.544       0.381
# Provider Type of Gynaecologist Appointment_Public    -0.0068      0.279     -0.024      0.981      -0.553       0.540
# Provider Type of Gynaecologist Appointment_nan       -0.3376      0.356     -0.948      0.343      -1.036       0.360
# =====================================================================================================================
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\genmod\families\links.py:13: FutureWarning: The cloglog link alias is deprecated. Use CLogLog instead. The cloglog link alias will be removed after the 0.15.0 release.
#   warnings.warn(

# %%
print(model_probit.aic)
print(model.aic)
print(model_cloglog.aic)
# Out:
# 216.58463706839956
# 219.12706495582302
# 216.23680943484456

# %%
print(model_probit.bic)
print(model.bic)
print(model_cloglog.bic)
# Out:
# 245.2206890210283
# 228.67241560669927
# -677.4846105645179
# D:\Program Files\anacondav2\envs\cervix_compliance\Lib\site-packages\statsmodels\genmod\generalized_linear_model.py:1923: FutureWarning: The bic value is computed using the deviance formula. After 0.13 this will change to the log-likelihood based formula. This change has no impact on the relative rank of models compared using BIC. You can directly access the log-likelihood version using the `bic_llf` attribute. You can suppress this message by calling statsmodels.genmod.generalized_linear_model.SET_USE_BIC_LLF with True to get the LLF-based version now or False to retainthe deviance version.
#   warnings.warn(

# %%
import numpy as np

infl = model.get_influence()
cooks_d = infl.cooks_distance[0]

# Identify influential points
influential_points = np.where(cooks_d > 4 / len(X))[0]
print("Influential Points:", influential_points)
# Out:
# Influential Points: [ 18  22  67  74 140 172]

# %%
from sklearn.ensemble import RandomForestClassifier

# Fit a Random Forest model
rf = RandomForestClassifier()
rf.fit(X, sub_y['y_Non-Compliant'])

# Feature importance (interactions may be needed if two variables are important)
importances = pd.Series(rf.feature_importances_, index=X.columns)
print(importances.sort_values(ascending=False))
# Out:
# SEIFA Score                                          0.405568
# Age                                                  0.372072
# Metro                                                0.044752
# Stage Simplified_III/IV                              0.041575
# In Area/Out of Area_Out of Area                      0.036666
# Provider Type of Gynaecologist Appointment_Public    0.036494
# Route of Referral_GP Referred                        0.035166
# Provider Type of Gynaecologist Appointment_nan       0.027707
# dtype: float64
